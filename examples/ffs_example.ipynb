# %%
import os
import numpy as np

from astropy.io import fits
from pyaraucaria.ffs import FFS

fits_path = "~/work/data/fits_examples/jk15c_0154_73367.fits"

# %%
hdul = fits.open(fits_path)
data = hdul[0].data
hdr = hdul[0].header
hdul.close()

# %%
# example 1 (simple)

ffs = FFS(data)
ffs.saturation = 50000
ffs.calc_frame_fwhm(threshold=10, fwhm=10, box=10, N_stars=20, clip=4)

for k in ffs.stats["frame"].keys():
    #print(f'{k}: {ffs.stats["frame"][k]} // {ffs.stats_description["frame"][k]}')
    print(f'{k}: {ffs.stats["frame"][k]}')
# Out:
# min: 1139
# max: 26988
# mean: 1218.0723501946468
# median: 1217
# rms: 112.22989608053216
# q_sigma_lower: 9
# q_sigma_upper: 10
# q_sigma: 9.5
# noise: 34.88552708502482
# fwhm: 4.667488484463641
# fwhm_x: 4.441727666033736
# fwhm_y: 5.0221869475809555
# ellipticity: 0.0953595473005695
# theta_spread: 0.20012003925799998
# cpe: 0.038271112213748695
# shape: 0.8218540139982152
# ci: 0.45178018795604896
# used_stars: 17

# %%
ffs = FFS(data)
ffs.saturation = 50000
ffs.mk_stats()
ffs.sky_gradient(n_segments=10)
ffs.find_lines()
ffs.find_stars(threshold=10,fwhm=3)
ffs.star_info(box=15,N_stars=20)
ffs.calc_star_stats()

for k in ffs.stats["frame"].keys():
    print(f'{k}: {ffs.stats["frame"][k]} // {ffs.stats_description["frame"][k]}')
# Out:
# min: 1139 // Minimal pixel value in the image
# max: 26988 // Maximum pixel value in the image
# mean: 1218.0723501946468 // Mean pixel value (arithmetic average)
# median: 1217 // Median pixel value (robust background estimator)
# rms: 112.22989608053216 // Standard deviation of pixel values
# q_sigma_lower: 9 // Lower 1-sigma estimate from 50% - 15.9% quantile
# q_sigma_upper: 10 // Upper 1-sigma estimate from 84.1% - 50% quantile
# q_sigma: 9.5 // Robust sigma estimated from 15.9–84.1% quantiles
# noise: 34.88552708502482 // Expected total noise (Poisson + read noise)
# bkg_max_amplitude: 11.697638781464093 // Maximum amplitude of the background signal across the image (in ADU)
# bkg_frame_gradient: 9.524216060461413 // Background gradient across the image frame (in ADU)
# sky_surface_coeff: [ 1.22051160e+03  4.65314346e-03 -8.00315246e-03 -1.56294961e-06
#   9.33461604e-07  1.46330632e-06] // Coefficients of the fitted sky model describing the sky background variation across the image
# fwhm: 4.71831969106158 // Median of the full width at half maximum (FWHM) of the brightest sources in the frame
# fwhm_x: 4.46272747371967 // Median FWHM measured along the X axis
# fwhm_y: 5.071852075211212 // Median FWHM measured along the Y axis
# ellipticity: 0.07217442717496259 // Median source ellipticity (1 − b/a), describing PSF elongation
# theta_spread: 0.183897836992033 // Angular spread (dispersion) of source position angles in the frame. Low spread with hight ellipticity means something
# cpe: 0.036015341179327864 // Median central pixel excess (CPE) of detected sources; higher values indicate sharper, more centrally concentrated profiles
# shape: 0.7988834656430901 // Median PSF shape parameter defined as CPE × FWHM^2
# ci: 0.4508844313742703 // Median concentration index (CI) of detected stars in the frame;
# used_stars: 17 // How many star were used to evaluate thos statistics

# %%
ffs = FFS(data)
ffs.saturation = 50000
ffs.mk_stats()
for k in ffs.stats.keys():
    print(f'{k}: {ffs.stats[k]} // {ffs.stats_description[k]}')

print(f'again, q_sigma: {ffs.q_sigma}')

ffs.sky_gradient(n_segments=10)

print(f'amplitude: {ffs.stats["frame"]["bkg_max_amplitude"]}')
print(f'frame gradient: {ffs.stats["frame"]["bkg_frame_gradient"]}')
print(f'coeff: {ffs.stats["frame"]["sky_surface_coeff"]}')

print(ffs.stats["sky"].keys())


ffs.maska = data > np.median(data) + 5 * ffs.q_sigma
ffs.hough_transform()

print(len(ffs.lines_val),ffs.lines_val[0])
#ffs.lines_rho
#ffs.lines_theta

#ffs.find_stars(threshold=10,fwhm=3)
#print(len(ffs.coo),len(ffs.adu))

#ffs.star_info(box=15,N_stars=20)
#print(len(ffs.fwhm),len(ffs.ellipticity),len(ffs.cpe))
# ffs.theta
# ffs.fwhm_x
# ffs.fwhm_y
# Out:
# frame: {'min': np.uint16(1139), 'max': np.uint16(26988), 'mean': np.float64(1218.0723501946468), 'median': np.uint16(1217), 'rms': np.float64(112.22989608053216), 'q_sigma_lower': np.uint16(9), 'q_sigma_upper': np.uint16(10), 'q_sigma': np.float64(9.5), 'noise': np.float64(34.88552708502482)} // {'min': 'Minimal pixel value in the image', 'max': 'Maximum pixel value in the image', 'mean': 'Mean pixel value (arithmetic average)', 'median': 'Median pixel value (robust background estimator)', 'rms': 'Standard deviation of pixel values', 'q_sigma_lower': 'Lower 1-sigma estimate from 50% - 15.9% quantile', 'q_sigma_upper': 'Upper 1-sigma estimate from 84.1% - 50% quantile', 'q_sigma': 'Robust sigma estimated from 15.9–84.1% quantiles', 'noise': 'Expected total noise (Poisson + read noise)'}
# stars: {} // {}
# again, q_sigma: 9.5
# amplitude: 11.697638781464093
# frame gradient: 9.524216060461413
# coeff: [ 1.22051160e+03  4.65314346e-03 -8.00315246e-03 -1.56294961e-06
#   9.33461604e-07  1.46330632e-06]
# dict_keys(['surface_bkg', 'surface_x', 'surface_y'])
# 6 123.0
